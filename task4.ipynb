# %% [markdown]
# ![1723190055120.jpeg](attachment:1723190055120.jpeg)

# %% [markdown]
# # Task-4
#
# ## Encoded Message: ##$$$@!yalpstcejorp EPUVT****9887

# %% [markdown]
# ## Steps to Decode:

# %% [markdown]
# ### 1. Extract the core part of the message: "yalpstcejorp EPUVT".

# %%
str= "##$$$@!yalpstcejorp EPUVT****9887" 
print(str[7:25])
# Out:
# yalpstcejorp EPUVT

# %% [markdown]
# ### 2. Reverse the first word: "yalpstcejorp" becomes "projectplay".

# %%
x= str[7:19]
rvs= x[::-1]
print(rvs)
# Out:
# projectsplay

# %% [markdown]
# ### 3. Replace shifted vowels in the second word:
# #### o "EPUVT": Replace E->A, U->O to get "APOVT".

# %%
y= str[20:25]
z= y.replace("E","A").replace("U","O")
print(z)
# Out:
# APOVT

# %% [markdown]
# ### 4. Final decoded message: "projectplay APTOV".

# %%
print(rvs,z)
# Out:
# projectsplay APOVT
